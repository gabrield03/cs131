# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrield03/cs131/blob/master/ExtractData/Capstone_Project_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Group 7 Mini Project - Glassdoor Job Postings Analysis
#
# Gabriel Larot, Thi Dao Nguyen Pham, and James Kim

# %% [markdown]
# # Import and display the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as clrs
from matplotlib import colormaps
# %matplotlib inline

# !wget -O dsj.csv https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/DataScientist.csv

df0 = pd.read_csv("dsj.csv",encoding='latin-1')
df0
# Out:
# --2023-12-04 00:45:42--  https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/DataScientist.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14957616 (14M) [text/plain]
# Saving to: ‘dsj.csv’
#
# dsj.csv             100%[===================>]  14.26M  --.-KB/s    in 0.1s
#
# 2023-12-04 00:45:42 (105 MB/s) - ‘dsj.csv’ saved [14957616/14957616]
#       Unnamed: 0  index                                          Job Title  \
# 0              0      0                              Senior Data Scientist
# 1              1      1                  Data Scientist, Product Analytics
# 2              2      2                               Data Science Manager
# 3              3      3                                       Data Analyst
# 4              4      4                             Director, Data Science
# ...          ...    ...                                                ...
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                             Data Analyst Ã¢ Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3904   $55K-$112K (Glassdoor est.)
# 3905   $55K-$112K (Glassdoor est.)
# 3906   $55K-$112K (Glassdoor est.)
# 3907   $55K-$112K (Glassdoor est.)
# 3908   $55K-$112K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, weâre on a missio...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\nDescription...     3.4
# ...                                                 ...     ...
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                                Company Name       Location      Headquarters  \
# 0                               Hopper\n3.5   New York, NY  Montreal, Canada
# 1                              Noom US\n4.5   New York, NY      New York, NY
# 2                                  Decode_M   New York, NY      New York, NY
# 3                     Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4           United Entertainment Group\n3.4   New York, NY      New York, NY
# ...                                     ...            ...               ...
# 3904              Tachyon Technologies\n4.4     Dublin, OH        Irving, TX
# 3905  Staffigo Technical Services, LLC\n5.0   Columbus, OH     Woodridge, IL
# 3906                    PDS Tech, Inc.\n3.8     Dublin, OH        Irving, TX
# 3907        Data Resource Technologies\n4.0     Dublin, OH         Omaha, NE
# 3908                               UCB\n3.7     Slough, OH  Brussel, Belgium
#
#                          Size  Founded  Type of ownership  \
# 0       501 to 1000 employees     2007  Company - Private
# 1      1001 to 5000 employees     2008  Company - Private
# 2           1 to 50 employees       -1            Unknown
# 3        201 to 500 employees     2019  Company - Private
# 4         51 to 200 employees     2007  Company - Private
# ...                       ...      ...                ...
# 3904     201 to 500 employees     2011  Company - Private
# 3905      51 to 200 employees     2008  Company - Private
# 3906  5001 to 10000 employees     1977  Company - Private
# 3907        1 to 50 employees       -1  Company - Private
# 3908  5001 to 10000 employees       -1   Company - Public
#
#                        Industry                     Sector  \
# 0               Travel Agencies           Travel & Tourism
# 1     Health, Beauty, & Fitness          Consumer Services
# 2                            -1                         -1
# 3                      Internet     Information Technology
# 4       Advertising & Marketing          Business Services
# ...                         ...                        ...
# 3904                IT Services     Information Technology
# 3905                IT Services     Information Technology
# 3906     Staffing & Outsourcing          Business Services
# 3907                 Accounting         Accounting & Legal
# 3908  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#                          Revenue               Competitors Easy Apply
# 0       Unknown / Non-Applicable                        -1         -1
# 1       Unknown / Non-Applicable                        -1         -1
# 2       Unknown / Non-Applicable                        -1       True
# 3       Unknown / Non-Applicable      Zocdoc, Healthgrades         -1
# 4       Unknown / Non-Applicable  BBDO, Grey Group, Droga5         -1
# ...                          ...                       ...        ...
# 3904    $10 to $25 million (USD)                        -1         -1
# 3905   $50 to $100 million (USD)                        -1         -1
# 3906  $100 to $500 million (USD)                        -1         -1
# 3907  Less than $1 million (USD)                        -1         -1
# 3908      $2 to $5 billion (USD)                    AbbVie         -1
#
# [3909 rows x 17 columns]

# %% [markdown]
# # Info for dataset

# %%
df0.describe()
# Out:
#         Unnamed: 0        index       Rating      Founded
# count  3909.000000  3909.000000  3909.000000  3909.000000
# mean   1954.000000  2167.446662     3.283576  1479.154771
# std    1128.575429  1247.657849     1.575749   855.750138
# min       0.000000     0.000000    -1.000000    -1.000000
# 25%     977.000000  1121.000000     3.200000  1625.000000
# 50%    1954.000000  2161.000000     3.700000  1976.000000
# 75%    2931.000000  3249.000000     4.100000  2002.000000
# max    3908.000000  4379.000000     5.000000  2020.000000

# %% [markdown]
# # Visualize the unique values from the columns

# %%
for col in df0:
  unique_values = df0[col].unique()
  num_unique = df0[col].nunique()
  print(f"Column '{col}' has {num_unique} unique value(s): {unique_values}")
# Out:
# Column 'Unnamed: 0' has 3909 unique value(s): [   0    1    2 ... 3906 3907 3908]
# Column 'index' has 3909 unique value(s): [   0    1    2 ... 4377 4378 4379]
# Column 'Job Title' has 2079 unique value(s): ['Senior Data Scientist' 'Data Scientist, Product Analytics'
#  'Data Science Manager' ... 'Cyber Security Data Engineer'
#  'Security Analytics Data Engineer'
#  'Patient Safety Physician or Safety Scientist - UK, Europe or the US']
# Column 'Salary Estimate' has 148 unique value(s): ['$111K-$181K (Glassdoor est.)' '$120K-$140K (Glassdoor est.)'
#  '$119K-$147K (Glassdoor est.)' '$74K-$124K (Glassdoor est.)'
#  '$102K-$121K (Glassdoor est.)' '$129K-$210K (Glassdoor est.)'
#  '$156K-$254K (Glassdoor est.)' '$116K-$152K (Glassdoor est.)'
#  '$133K-$171K (Glassdoor est.)' '$110K-$139K (Glassdoor est.)'
#  '$82K-$141K (Glassdoor est.)' '$96K-$119K (Glassdoor est.)'
#  '$146K-$175K (Glassdoor est.)' '$102K-$164K (Glassdoor est.)'
#  '$113K-$180K (Glassdoor est.)' '$76K-$122K (Glassdoor est.)'
#  '$134K-$218K (Glassdoor est.)' '$76K-$125K (Glassdoor est.)'
#  '$132K-$208K (Glassdoor est.)' '$83K-$105K (Glassdoor est.)'
#  '$75K-$143K (Glassdoor est.)' '$34K-$72K (Glassdoor est.)'
#  '$37K-$75K (Glassdoor est.)' '$113K-$184K (Glassdoor est.)'
#  '$136K-$164K (Glassdoor est.)' '$34-$53 Per Hour(Glassdoor est.)'
#  '$46K-$80K (Glassdoor est.)' '$79K-$130K (Glassdoor est.)'
#  '$91K-$105K (Glassdoor est.)' '$31K-$56K (Glassdoor est.)'
#  '$39K-$81K (Glassdoor est.)' '$99K-$174K (Glassdoor est.)'
#  '$76K-$147K (Glassdoor est.)' '$62K-$109K (Glassdoor est.)'
#  '$70K-$123K (Glassdoor est.)' '$40K-$73K (Glassdoor est.)'
#  '$38K-$59K (Glassdoor est.)' '$60K-$105K (Glassdoor est.)'
#  '$69K-$144K (Glassdoor est.)' '$47K-$82K (Glassdoor est.)'
#  '$90K-$175K (Glassdoor est.)' '$39K-$87K (Glassdoor est.)'
#  '$36K-$71K (Glassdoor est.)' '$55K-$117K (Glassdoor est.)'
#  '$114K-$144K (Glassdoor est.)' '$138K-$217K (Glassdoor est.)'
#  '$72K-$97K (Glassdoor est.)' '$73K-$136K (Glassdoor est.)'
#  '$10-$26 Per Hour(Glassdoor est.)' '$94K-$151K (Glassdoor est.)'
#  '$97K-$159K (Glassdoor est.)' '$46K-$104K (Glassdoor est.)'
#  '$45K-$81K (Glassdoor est.)' '$92K-$144K (Glassdoor est.)'
#  '$64K-$97K (Glassdoor est.)' '$47K-$73K (Glassdoor est.)'
#  '$84K-$156K (Glassdoor est.)' '$97K-$111K (Glassdoor est.)'
#  '$84K-$101K (Glassdoor est.)' '$99K-$173K (Glassdoor est.)'
#  '$93K-$151K (Glassdoor est.)' '$50K-$87K (Glassdoor est.)'
#  '$71K-$117K (Glassdoor est.)' '$44K-$80K (Glassdoor est.)'
#  '$94K-$166K (Glassdoor est.)' '$65K-$100K (Glassdoor est.)'
#  '$41K-$74K (Glassdoor est.)' '$46K-$83K (Glassdoor est.)'
#  '$45K-$106K (Glassdoor est.)' '$71K-$122K (Glassdoor est.)'
#  '$143K-$237K (Glassdoor est.)' '$70K-$154K (Glassdoor est.)'
#  '$68K-$89K (Glassdoor est.)' '$55K-$101K (Glassdoor est.)'
#  '$98K-$152K (Glassdoor est.)' '$54K-$92K (Glassdoor est.)'
#  '$74K-$140K (Glassdoor est.)' '$83K-$154K (Glassdoor est.)'
#  '$52K-$91K (Glassdoor est.)' '$43K-$76K (Glassdoor est.)'
#  '$17-$27 Per Hour(Glassdoor est.)' '$114K-$146K (Glassdoor est.)'
#  '$60K-$124K (Glassdoor est.)' '$46K-$82K (Glassdoor est.)'
#  '$83K-$165K (Glassdoor est.)' '$39K-$69K (Glassdoor est.)'
#  '$88K-$140K (Glassdoor est.)' '$74K-$129K (Glassdoor est.)'
#  '$114K-$211K (Glassdoor est.)' '$75K-$149K (Glassdoor est.)'
#  '$112K-$211K (Glassdoor est.)' '$62K-$127K (Glassdoor est.)'
#  '$86K-$178K (Glassdoor est.)' '$110K-$169K (Glassdoor est.)'
#  '$12K-$112K (Glassdoor est.)' '$12K-$111K (Glassdoor est.)'
#  '$134K-$210K (Glassdoor est.)' '$49K-$78K (Glassdoor est.)'
#  '$48K-$98K (Glassdoor est.)' '$85K-$159K (Glassdoor est.)'
#  '$51K-$79K (Glassdoor est.)' '$49K-$92K (Glassdoor est.)'
#  '$85K-$147K (Glassdoor est.)' '$45K-$78K (Glassdoor est.)'
#  '$48K-$89K (Glassdoor est.)' '$46K-$91K (Glassdoor est.)'
#  '$73K-$102K (Glassdoor est.)' '$100K-$172K (Glassdoor est.)'
#  '$93K-$149K (Glassdoor est.)' '$148K-$174K (Glassdoor est.)'
#  '$111K-$175K (Glassdoor est.)' '$150K-$237K (Glassdoor est.)'
#  '$200K-$250K(Employer est.)' '$135K-$214K (Glassdoor est.)'
#  '$119K-$188K (Glassdoor est.)' '$145K-$176K (Glassdoor est.)'
#  '$150K-$169K (Glassdoor est.)' '$121K-$192K (Glassdoor est.)'
#  '$141K-$225K (Glassdoor est.)' '$102K-$179K (Glassdoor est.)'
#  '$116K-$181K (Glassdoor est.)' '$112K-$178K (Glassdoor est.)'
#  '$100K-$152K (Glassdoor est.)' '$38K-$68K (Glassdoor est.)'
#  '$73K-$111K (Glassdoor est.)' '$82K-$129K(Employer est.)'
#  '$74K-$144K (Glassdoor est.)' '$41K-$66K (Glassdoor est.)'
#  '$59K-$113K (Glassdoor est.)' '$70K-$129K (Glassdoor est.)'
#  '$50K-$110K (Glassdoor est.)' '$62K-$112K (Glassdoor est.)'
#  '$114K-$185K (Glassdoor est.)' '$61K-$94K (Glassdoor est.)'
#  '$54K-$88K (Glassdoor est.)' '$66K-$130K (Glassdoor est.)'
#  '$96K-$155K (Glassdoor est.)' '$57K-$80K (Glassdoor est.)'
#  '$47K-$84K (Glassdoor est.)' '$39K-$71K (Glassdoor est.)'
#  '$55K-$98K (Glassdoor est.)' '$93K-$103K (Glassdoor est.)'
#  '$100K-$163K (Glassdoor est.)' '$98K-$160K (Glassdoor est.)'
#  '$52K-$94K (Glassdoor est.)' '$55K-$113K (Glassdoor est.)'
#  '$39K-$86K (Glassdoor est.)' '$55K-$112K (Glassdoor est.)']
# Column 'Job Description' has 3685 unique value(s): ['ABOUT HOPPER\n\nAt Hopper, weâ\x80\x99re on a mission to make booking travel faster, easier, and more transparent. We are leveraging the power that comes from combining massive amounts of data and machine learning to build the worldâ\x80\x99s fastest-growing travel app -- one that enables our customers to save money and travel more. With over $235M CAD in funding from leading investors in both Canada and the US, Hopper is primed to continue its path toward becoming the go-to way to book travel as the world continues its shift to mobile.\n\nRecognized as the fastest-growing travel app by Forbes and one of the worldâ\x80\x99s most innovative companies by Fast Company two years in a row, Hopper has been downloaded over 40 million times and has helped travelers plan over 100 million trips and counting. The app has received high praise in the form of mobile accolades such as the Webby Award for Best Travel App of 2019, the Google Play Award for Standout Startup of 2016 and Appleâ\x80\x99s App Store Best of 2015.\n\nTake off with us!\n\nTHE ROLE\n\nHopper is looking for a data-savvy individual to join our team as a Data Scientist and lead data-centric product development and complex business intelligence projects within our core air travel business unit. Every day you would draw powerful insights from our real-time feed of billions of flight search results and archives of several trillion data points. To succeed at Hopper you need the talent, passion, and experience to thrive in a highly performing company.\nIN THIS ROLE YOU WILL:\nFrame and conduct complex exploratory analyses needed to deepen our understanding of Hopper users.\nPartner with product, business and strategy teams to leverage this user understanding for product improvements and other initiatives\nUse machine learning and big data tools on tremendously large and complex data sets to enhance our data-driven, personalized travel advice\nConduct research into various aspects of our business and employ statistical and modeling techniques when appropriate to make recommendations to non-technical stakeholders\nCreate advanced dashboards for product experiment tracking and business unit performance analysis using Amplitude and Tableau\nFind effective ways to simplify and communicate analyses to a non-technical audience.\nA PERFECT CANDIDATE HAS:\nA degree in Math, Statistics, Computer Science, Engineering or other quantitative disciplines\nExtremely strong analytical and problem-solving skills\nProven ability to communicate complex technical work to a non-technical audience\nA strong passion for and extensive experience in conducting empirical research and answering hard questions with data\nExperience with a data visualization tool (Tableau preferred) and project analysis tool such as Amplitude\nExperience with relational databases and SQL, especially Hive\nExperience working with extremely large data sets\nExperience in Pandas, R, SAS or other tools appropriate for large scale data preparation and analysis\nExperience with data mining, machine learning, statistical modeling tools and underlying algorithms\nProficiency with Unix/Linux environments\nBENEFITS\n\nâ\x80¢ Well-funded and proven startup with large ambitions, competitive salary and stock options\nâ\x80¢ Dynamic and entrepreneurial team where pushing limits is everyday business\nâ\x80¢ 100% employer paid medical, dental, vision, disability and life insurance plans\nâ\x80¢ Access to a 401k (US) or Retirement Savings Plan (Canada)'
#  'At Noom, we use scientifically proven methods to help our users create healthier lifestyles, and manage important conditions like Type-II Diabetes, Obesity, and Hypertension. Our Engineering team is at the forefront of this challenge, solving complex technical and UX problems on our mobile apps that center around habits, behavior, and lifestyle.\n\nWe are looking for a Data Scientist to join our Data team and help us ensure that we apply the best approaches to data analysis and research, artificial intelligence, and machine learning.\n\nWhat You\'ll Like About Us:\nWe work on problems that affect the lives of real people. Our users depend on us to make positive changes to their health and their lives.\nWe base our work on scientifically-proven, peer-reviewed methodologies that are designed by medical professionals.\nWe are a data-driven company through and through.\nWe\'re a respectful, diverse, and dynamic environment in which Engineering is a first-class citizen, and where you\'ll be able to work on a variety of interesting problems that affect the lives of real people.\nWe offer a generous budget for personal development expenses like training courses, conferences, and books.\nYou\'ll get three weeks\' paid vacation and a flexible work policy that is remote- and family-friendly (about 50% of our engineering team is fully remote). We worry about results, not time spent in seats.\nWhat We\'ll Like About You:\nYou have 4+ years of experience as a Data Scientist or Data Analyst in a similarly-sized organization, with a proven record of analysis and research that positively impacts your team.\nYou possess excellent communication skills and the ability to clearly communicate technical concepts to a non-technical audience\nYou possess excellent SQL/relational algebra skills, ideally with at least a basic knowledge of how different types of databases (e.g.: column vs row storage) work.\nYou have a superior knowledge of statistical analysis methods, such as input selection, logistic and standard regression, etc.\nYou are comfortable writing Python code, and have good working knowledge of pandas and numpy. We don\'t expect you to write production-quality code, but you should have some programming experience.\nYou are comfortable with at least "medium data" technologies and how to transcend the "memory bound" nature of most analytics tools.'
#  "Decode_M\n\nhttps://www.decode-m.com/\n\nData Science Manager : Job Description\n\nWeâ\x80\x99re hiring a Data Science Manager in our New York office to lead Decode_Mâ\x80\x99s Data Science team in developing new solutions for our clients and advancing the science of momentum through our proprietary product.\n\nThis position, based in New York City, requires an interest in managing Decode_Mâ\x80\x99s data science team, workflow and offerings. It demands excellent organizational skills, a natural curiosity, an eagerness to dive into the deep end, and a hunger to learn and grow while having a blast. Expect to learn a lot about cool companies, new products, and the latest in analytics, research and strategy.\n\nAbout You\nYou have an advanced degree in data science, mathematics, or another highly quantitative field, and are comfortable understanding and utilizing recent academic research in your work.\nYou have 3+ years of relevant work experience using applied statistics and/or machine learning. Bonus points if youâ\x80\x99ve worked in a consulting, or other client-facing role before\nYou have 1+ years of management experience.\nYou are fluent in Python and R, as well as a robust numerical computing and data science stack in each language. Not only do you produce readable and well-documented code, but elevate your teamâ\x80\x99s work through thoughtful code review and mentorship\nYou are highly consultative, engaged, and detail-oriented. You see beyond the question you are asked to understand client objectives, and chart a course for long-term success in our relationships\nYou are an autodidact, who loves to figure out new solutions to problems by diving deep into StackOverflow, Arxiv.org, or your preferred destination.\nYou are curious, inquisitive, proactive, organized, and methodical. You like to use substantiated data to both identify and solve problems, rather than trust your gut alone\n\n\nWhat You'll Do\n\nLead a team. Help to set the vision for the Data Science team and follow through on that vision. Be a mentor to a small, close-knit team of data scientists, helping them to develop professionally\n\nDrive New Product Development: Decode_M has developed a proprietary algorithm to quantify the cultural momentum of brands, entities, people and movements. You will steward the development of the algorithm and be part of the product team to bring it to market with new customers\n\nManage Process. Work across teams and with Decode_Mâ\x80\x99s leadership to ensure that our work is top notch, deadlines are met, and projects are resourced appropriately. Foster an environment where the team is empowered to do its best work\n\nBuild Tools. Use data from social media, online reviews, mainstream media sites, search, web traffic, quantitative research, CRMs or other databases, etc. to uncover intelligence around growth opportunities and business challenges. Build software and/or repeatable processes to scale this work\n\nGrow our Capabilities. Advance our expertise in applying statistics and machine learning to digital trends, CRM data, and quantitative research. Know the state of the field well enough to know when to reach for best-in-class tools and when to design your own solutions"
#  ...
#  "Job DescriptionThe Security Analytics Data Engineer will interface with security Big Data environments, aiding in their design and configuration, to analyze and present findings within them. The security engineer is expected to work independently with internal clients and management on information security issues and strategies, manage new and existing requirements and fully document processes and solutions. This role will require a deep understanding of security constructs in addition to a wide array of technologies to effectively perform the duties expected. This position will interface with several products and technologies, including not limited to: MSSQL (SSRS/SSIS/SSDT), Python, Splunk, ELK stack (Elastic, Kibana, Logstash), MongoDB/NoSQL, OLAP cubes, DLP, Tanium, MySQL, Oracle, among others. In addition, design and developing of portals, processes and procedures will be required for incident response and security reporting.\n\nJob Specific Responsibilities\nPerform analysis across various data sets to identify baselines, working towards defining a predictive capability\nMonitor, maintain and refresh production machine learning models\nIdentify data sources both internally and externally that can be used to improve insight into activity, implement data exploration technologies accordingly\nAnalyze data to enable a better understanding of each data source\nCreate presentation dashboards and implement analytical tools to enhance action of the discoveries\nAid in design, development, and management of a large scale Elastic/ELK environment including data ingestion capabilities and underlying infrastructure\n\nCandidate Requirements\nFundamental knowledge of firewalls, networking, operating systems, databases, and storage, both at a functional level to understand data that is in scope\nExperience with Big Data frameworks (Elastic/ELK preferred), querying tools and analytics tools in a large scale implementation in an Enterprise environment\nRegex/Scripting/programming/RDBMS knowledge (shell, batch, perl, python, php, Oracle, MSSQL, others)\nData modeling and schema design\nMust have excellent verbal and written communication skills with experience presenting information to groups\nMust have strong analytical, technical, and problem solving skills\nAbility to demonstrate leadership qualities and skills, including independent decision-making abilities.\nAbility to manage time and priorities with multiple tasks and projects.\nAbility to work with loosely defined requirements.\nSelf-starter mentality and the ability to think outside the box.\n\nPreferred Qualifications\n10+ yrs. of related IT experience\n3+ years MS SQL, SSDT\nReporting Experience a big plus (SSRS, Power BI, Kibana, Tableau)\nWeb Development Experience desired\n3+ years of Big Data platform experience (ELK, Mongo, Hadoop, et al.); Design, management and operation\nExpert knowledge of Unix/Linux (RHEL preferred) and/or Windows OSes, including infrastructure Engineering and Support\nMS preferred or Bachelors Degree with equivalent work experience and appropriate certifications\nStrong understanding of how technology relates to business, market and industry and applies knowledge to support the needs of critical systems and projects.\nA solid understanding of Network and Endpoint Systems Scanning\nExperience with repository management systems (GIT, etc).\nExperience with SIEM (Security Information and Event Management) systems, and security event correlation or other Information Security models.\nExperience with enterprise-scale operations and maintenance environments\n\nPDS Tech, Inc. is an Equal Opportunity Employer. All qualified applicants will receive consideration for employment without regard to race, color, sex, sexual orientation, gender identity, religion, national origin, disability, veteran status, age, marital status, pregnancy, genetic information, or other legally protected status.\n\nFounded in 1977, PDS Tech, Inc. is one of the nation's premier spe ...
#  'The Security Analytics Data Engineer will interface with security Big Data environments, aiding in their design and configuration, to analyze and present findings within them. The security engineer is expected to work independently with internal clients and management on information security issues and strategies, manage new and existing requirements and fully document processes and solutions. This role will require a deep understanding of security constructs in addition to a wide array of technologies to effectively perform the duties expected. This position will interface with several products and technologies, including not limited to MSSQL (SSRSSSISSSDT), Python, Splunk, ELK stack (Elastic, Kibana, Logstash), MongoDBNoSQL, OLAP cubes, DLP, Tanium, MySQL, Oracle, among others. In addition, design and developing of portals, processes and procedures will be required for incident response and security reporting. Job Specific Responsibilities Perform analysis across various data sets to identify baselines, working towards defining a predictive capability. Monitor, maintain and refresh production machine learning models. Identify data sources both internally and externally that can be used to improve insight into activity, implement data exploration technologies accordingly. Analyze data to enable a better understanding of each data source. Create presentation dashboards and implement analytical tools to enhance action of the discoveries. Aid in design, development, and management of a large scale. ElasticELK environment including data ingestion capabilities and underlying infrastructure. Candidate Requirements Fundamental knowledge of firewalls, networking, operating systems, databases, and storage, both at a functional level to understand data that is in scope Experience with Big Data frameworks (ElasticELK preferred), querying tools and analytics tools in a large scale implementation in an Enterprise environment RegexScriptingprogrammingRDBMS knowledge (shell, batch, perl, python, php, Oracle, MSSQL, others) Data modeling and schema design Must have excellent verbal and written communication skills with experience presenting information to groups Must have strong analytical, technical, and problem solving skills Ability to demonstrate leadership qualities and skills, including independent decision-making abilities. Ability to manage time and priorities with multiple tasks and projects. Ability to work with loosely defined requirements. Self-starter mentality and the ability to think outside the box. Preferred Qualifications 10+ yrs. of related IT experience 3+ years MS SQL, SSDT Reporting Experience a big plus (SSRS, Power BI, Kibana, Tableau) Web Development Experience desired 3+ years of Big Data platform experience (ELK, Mongo, Hadoop, et al.) Design, management and operation Expert knowledge of UnixLinux (RHEL preferred) andor Windows OSes, including infrastructure Engineering and Support MS preferred or Bachelorrsquos Degree with equivalent work experience and appropriate certifications Strong understanding of how technology relates to business, market and industry and applies knowledge to support the needs of critical systems and projects. A solid understanding of Network and Endpoint Systems Scanning Experience with repository management systems (GIT, etc). Experience with SIEM (Security Information and Event Management) systems, and security event correlation or other Information Security models. Experience with enterprise-scale operations and maintenance environments'
#  "Help us transform patients' lives.\nAt UCB, we put our heart, soul, and skills into making a difference for people living with severe disease. Working together to push the boundaries, we blend the best of our talents to unlock innovation. Will you join us in our pioneering adventure?\nPatient Safety Physician/Safety Scientist\nUK, Europe or US\nHelp us transform patientsâ\x80\x99 lives\nAbout UCB\nAt UCB, we put our heart, soul and skills into making a difference for people living with chronic disease. Working together to push the boundaries, we blend the best of our talents to unlock innovation. Will you join us in our pioneering adventure?\nTo strengthen our Global Patient Safety Group, we are looking to fill the position of: Patient Safety Physician/Safety Scientist. We currently have vacancies in the following teams:\n- Immunology Patient Safety Unit\n- Neurology Patient Safety Unit\n- New Medicines Patient Safety Unit\n- Bone and Rare Diseases Patient Safety Unit\nAbout the Role\nYou will:\nâ\x80¢ Be required to be a key contributor and assessor of the benefit-risk profile of products, including signal detection activities and risk minimisation strategies\nâ\x80¢ Provide support to the Safety Lead (SL) for Benefit Risk Team (BRT), Global Labelling Committee (GLC), Benefit Risk Board (BRB), and Patient Value Unit (PVU) activities\nâ\x80¢ Contribute to the scientific analysis and review of various sources of safety data (e.g. regulatory, clinical, submission, legal, product quality)\nAbout You\nYou will have:\nâ\x80¢ MD, PhD, PharmD, DVM or other relevant advanced degree\nâ\x80¢ Minimum of 2 years of pharmacovigilance experience which must include one or more areas from safety surveillance/signal detection and management, benefit-risk assessment or safety risk management in either the development or marketed setting\nâ\x80¢ Excellent English scientific writing and communication skills\nâ\x80¢ An ability to work in a matrix environment\nâ\x80¢ Formal training in analytic skills such as biostatistics or epidemiology\nâ\x80¢ Project management experience\nâ\x80¢ Previous experience in a relevant scientific field\nAbout us.\nUCB- Inspired by Patients. Driven by Science. Everything we do starts with a simple question: â\x80\x9cHow will this create value for people living with severe diseases?â\x80\x9d By putting patients at the heart of what we do, our approach â\x80\x93 from discovery to development to delivery â\x80\x93 is continuously transformed and designed around patient needs and their journey.\nWith a team of approximately 7,500 employees and operations in more than 40 countries, we are a global biopharmaceutical company investing more than a quarter of our revenue in cutting-edge scientific research. We are focused on addressing chronic, neurological, immunological, and bone diseases.\nCurious to know more? Please visit our website www.ucb.com.\nUCB and its subsidiaries encourage diversity and inclusion in the workplace; we are an Equal Opportunity Employer."]
# Column 'Rating' has 37 unique value(s): [ 3.5  4.5 -1.   3.4  2.9  4.4  5.   4.8  3.9  4.3  3.   3.6  3.3  4.
#   4.1  3.8  3.7  4.2  4.6  4.7  3.2  2.8  2.7  4.9  2.5  1.   1.9  3.1
#   1.6  2.6  2.1  2.3  2.4  2.   2.2  1.5  1.7]
# Column 'Company Name' has 2075 unique value(s): ['Hopper\n3.5' 'Noom US\n4.5' 'Decode_M' ...
#  'Creative Financial Staffing\n4.5' 'ComResource\n4.6'
#  'Data Resource Technologies\n4.0']
# Column 'Location' has 191 unique value(s): ['New York, NY' 'Lyndhurst, NJ' 'Brooklyn, NY' 'Jersey City, NJ'
#  'Carle Place, NY' 'Newark, NJ' 'Franklin Lakes, NJ' 'Port Washington, NY'
#  'Rockville Centre, NY' 'Queens Village, NY' 'Fort Lee, NJ'
#  'Middletown, NJ' 'Florham Park, NJ' 'Summit, NJ' 'Maywood, NJ'
#  'West Orange, NJ' 'Los Angeles, CA' 'Woodland Hills, CA'
#  'Universal City, CA' 'Anaheim, CA' 'Culver City, CA' 'Cerritos, CA'
#  'Santa Monica, CA' 'Torrance, CA' 'El Segundo, CA' 'Glendale, CA'
#  'Brea, CA' 'Burbank, CA' 'Westmont, CA' 'Pasadena, CA' 'Irwindale, CA'
#  'Calabasas, CA' 'Hermosa Beach, CA' 'Whittier, CA' 'Northridge, CA'
#  'Marina del Rey, CA' 'Monaco, CA' 'Venice, CA' 'Sherman Oaks, CA'
#  'Duarte, CA' 'Wilmington, CA' 'Long Beach, CA' 'Monrovia, CA'
#  'Carson, CA' 'Seal Beach, CA' 'Monterey Park, CA' 'Chicago, IL'
#  'Evanston, IL' 'Melrose Park, IL' 'Lemont, IL' 'Rosemont, IL'
#  'Northbrook, IL' 'Westmont, IL' 'Elmhurst, IL' 'Downers Grove, IL'
#  'Rolling Meadows, IL' 'Naperville, IL' 'Maywood, IL' 'Oak Brook, IL'
#  'Des Plaines, IL' 'Hines, IL' 'Evergreen Park, IL' 'Bridgeview, IL'
#  'Houston, TX' 'Alvin, TX' 'Stafford, TX' 'Pearland, TX' 'Spring, TX'
#  'Pasadena, TX' 'Sugar Land, TX' 'Webster, TX' 'Baytown, TX'
#  'Nassau Bay, TX' 'West University Place, TX' 'Missouri City, TX'
#  'Bellaire, TX' 'Scottsdale, AZ' 'Phoenix, AZ' 'Tempe, AZ' 'Chandler, AZ'
#  'Gilbert, AZ' 'Mesa, AZ' 'DC Ranch, AZ' 'Glendale, AZ' 'Luke AFB, AZ'
#  'Wilmington, DE' 'Newtown, PA' 'Philadelphia, PA' 'Blue Bell, PA'
#  'Gloucester City, NJ' 'Exton, PA' 'Camden, NJ' 'Valley Forge, PA'
#  'Bala Cynwyd, PA' 'King of Prussia, PA' 'Conshohocken, PA'
#  'West Chester, PA' 'Wayne, PA' 'Horsham, PA' 'Collegeville, PA'
#  'Spring House, PA' 'Fort Washington, PA' 'Stevenage, United Kingdom'
#  'Springhouse Branch Post Office, PA' 'Boothwyn, PA' 'Bensalem, PA'
#  'West Conshohocken, PA' 'Feasterville Trevose, PA' 'Malvern, PA'
#  'Paoli, PA' 'Allegheny West, PA' 'Radnor, PA' 'Plymouth Meeting, PA'
#  'Bristol, PA' 'Brentford, United Kingdom' 'Doylestown, PA'
#  'Chester Township, PA' 'Ridley Park, PA' 'Mount Laurel, NJ'
#  'West Point, PA' 'Warminster, PA' 'Cherry Hill, NJ' 'Pennsauken, NJ'
#  'Media, PA' 'Berwyn, PA' 'Norristown, PA' 'North Wales, PA'
#  'San Antonio, TX' 'Schertz, TX' 'Lackland AFB, TX' 'Fort Sam Houston, TX'
#  'San Diego, CA' 'Poway, CA' 'La Jolla, CA' 'Chula Vista, CA'
#  'National City, CA' 'Dallas, TX' 'Allen, TX' 'Plano, TX' 'Richardson, TX'
#  'Arlington, TX' 'Grapevine, TX' 'Grand Prairie, TX' 'Irving, TX'
#  'Addison, TX' 'Lewisville, TX' 'Coppell, TX' 'Farmers Branch, TX'
#  'Carrollton, TX' 'Southlake, TX' 'Bedford, TX' 'Cupertino, CA'
#  'Palo Alto, CA' 'San Jose, CA' 'Santa Clara, CA' 'San Francisco, CA'
#  'Redwood City, CA' 'Mountain View, CA' 'West Menlo Park, CA'
#  'Menlo Park, CA' 'Fremont, CA' 'San Carlos, CA' 'Union City, CA'
#  'Sunnyvale, CA' 'Livermore, CA' 'Pleasanton, CA' 'East Palo Alto, CA'
#  'Stanford, CA' 'Newark, CA' 'Campbell, CA' 'Los Gatos, CA'
#  'Los Altos, CA' 'Milpitas, CA' 'Austin, TX' 'Round Rock, TX'
#  'West Lake Hills, TX' 'Cedar Park, TX' 'Kyle, TX' 'Jacksonville, FL'
#  'Jacksonville Beach, FL' 'Fort Worth, TX' 'Westlake, TX' 'Columbus, OH'
#  'Gahanna, OH' 'West Jefferson, OH' 'Westerville, OH' 'Lockbourne, OH'
#  'Dublin, OH' 'Slough, OH' 'Blacklick, OH' 'Hilliard, OH']
# Column 'Headquarters' has 543 unique value(s): ['Montreal, Canada' 'New York, NY' 'Lyndhurst, NJ' 'Hartford, CT'
#  'Stamford, CT' 'Brooklyn, NY' 'London, United Kingdom' 'Burbank, CA'
#  'Chicago, IL' 'Jacksonville, FL' 'Stockholm, Sweden' 'San Francisco, CA'
#  'Memphis, TN' 'Warren, MI' 'Berlin, Germany' 'Menlo Park, CA'
#  'Marina del Rey, CA' 'Washington, DC' '-1' 'San Jose, CA' 'Seattle, WA'
#  'Reading, MA' 'Iselin, NJ' 'Norwalk, CT' 'Tehran, Iran' 'Jersey City, NJ'
#  'Greenwich, CT' 'Mountain View, CA' 'Langley, VA' 'Princeton, NJ'
#  'Wichita, KS' 'East Northport, NY' 'South Plainfield, NJ' 'Medford, OR'
#  'Bengaluru, India' 'North Brunswick, NJ' 'Baltimore, MD' 'Plainsboro, NJ'
#  'Newark, NJ' 'San Diego, CA' 'Mc Lean, VA' 'New York, NY (US), NY'
#  'Santa Monica, CA' 'San Antonio, TX' 'Coconut Creek, FL'
#  'Port Washington, NY' 'MINATO-KU, Japan' 'Carle Place, NY'
#  'Rockville Centre, NY' 'Piscataway, NJ' 'Ventura, CA' 'Dublin, Ireland'
#  'Walpole, MA' 'Fair Lawn, NJ' 'Litchfield Park, AZ' 'Columbus, OH'
#  'Milwaukee, WI' 'Hamilton, Bermuda' 'Cambridge, United Kingdom'
#  'Cherry Hill, NJ' 'Kings Langley, United Kingdom' 'Fort Lee, NJ'
#  'Irvine, CA' 'Charlotte, NC' 'Armonk, NY' 'Southfield, MI'
#  'San Mateo, CA' 'Colorado Springs, CO' 'Louisville, KY'
#  'West Hollywood, CA' 'Bethesda, MD' 'Edison, NJ' 'Bellevue, WA'
#  'Toronto, Canada' 'Irving, TX' 'Sydney, Australia' 'Fairfax, VA'
#  'Fremont, CA' 'Calistoga, CA' 'Phoenix, AZ' 'Houston, TX'
#  'Salt Lake City, UT' 'Los Angeles, CA' 'Springfield, MA' 'Cleveland, OH'
#  'Gibsonia, PA' 'Palo Alto, CA' 'Woodland Hills, CA' 'Los Gatos, CA'
#  'Culver City, CA' 'Easton, MD' 'Sherman Oaks, CA' 'El Segundo, CA'
#  'Encino, CA' 'Glendale, CA' 'Brea, CA' 'Paris, France' 'Redwood City, CA'
#  'Atlanta, GA' 'North Hollywood, CA' 'Sterling, VA' 'Duarte, CA'
#  'Calabasas, CA' 'Markham, Canada' 'Rutland, VT' 'Hermosa Beach, CA'
#  'Bedford, MA' 'Maidenhead, United Kingdom' 'Cupertino, CA'
#  'West Roxbury, MA' 'Alpharetta, GA' 'Barcelona, Spain'
#  'Seoul, South Korea' 'Van Nuys, CA' 'Denver, CO' 'Berwyn, PA' 'Troy, MI'
#  'South San Francisco, CA' 'Foster City, CA' 'Parsippany, NJ'
#  'Pasadena, CA' 'Bishnupur , India' 'Naperville, IL' 'Milton, WV'
#  'Woodridge, IL' 'Venice, CA' 'Glen Allen, VA' 'South Jordan, UT'
#  'Sacramento, CA' 'Rolling Meadows, IL' 'Melbourne, Australia'
#  'Austin, TX' 'Centennial, CO' 'Waltham, MA' 'Hillsborough, NJ'
#  'Aliso Viejo, CA' 'Norwood, MA' 'Westlake Village, CA' 'Costa Mesa, CA'
#  'Pleasanton, CA' 'Dana Point, CA' 'Oakland, CA' 'Long Beach, CA'
#  'Luxembourg, Luxembourg' 'Quebec, Canada' 'Tacoma, WA' 'Walnut Creek, CA'
#  'King of Prussia, PA' 'Tempe, AZ' 'South Windsor, CT' 'Dallas, TX'
#  'Tampa, FL' 'Harrisburg, NC' 'Indianapolis, IN' 'Williamsville, NY'
#  'Hayward, CA' 'Santa Clara, CA' 'Cincinnati, OH' 'Hyderabad, India'
#  'Alhambra, CA' 'Burlington, NC' 'Evanston, IL' 'Rosemont, IL'
#  'Duluth, GA' 'Jenkintown, PA' 'Minneapolis, MN' 'Madison, WI'
#  'Muscatine, IA' 'Hinsdale, IL' 'Chennai, India' 'Langhorne, PA'
#  'Lemont, IL' 'Milan, IL' 'Deerfield, IL' 'McLean, VA' 'Woonsocket, RI'
#  'Fort Wayne, IN' 'Northbrook, IL' 'Turin, Italy' 'Oak Brook, IL'
#  'Park Ridge, IL' 'Aurora, Canada' 'Hanover, MD' 'Arlington Heights, IL'
#  'Gardena, CA' 'Miramar, FL' 'Reston, VA' 'Itasca, IL' 'Minnetonka, MN'
#  'Covington, KY' 'Matthews, NC' 'Kennesaw, GA' 'Pittsburgh, PA'
#  'Millersville, MD' 'Wilmington, DE' 'Berea, OH' 'Boston, MA'
#  'Somerset, NJ' 'St Thomas, VI' 'New Haven, CT' 'Brookfield, WI'
#  'Basking Ridge, NJ' 'Dublin, CA' 'Ottawa, Canada' 'Singapore, Singapore'
#  'Ashburn, VA' 'Wilmington, NC' 'New York, 061' 'Plano, TX' 'Dublin, OH'
#  'KIRKLAND, Canada' 'Burr Ridge, IL' 'Saint Louis, MO' 'Philadelphia, PA'
#  'Fort Lauderdale, FL' 'Portland, OR' 'Dayton, OH' 'Mississauga, Canada'
#  'Schaumburg, IL' 'Peoria, IL' 'Bridgeview, IL' 'Sayreville, NJ'
#  'Hilliard, OH' 'Raleigh, NC' 'Miami, FL' 'Des Plaines, IL' 'Boulder, CO'
#  'Rochester, NY' 'Warwick, United Kingdom' 'Stavanger, Norway'
#  'CARQUEFOU, France' 'San Carlos, CA' 'Canton, MI' 'Chadds Ford, PA'
#  'Clinton, MD' 'Bethlehem, PA' 'Stafford, TX' 'Ridgeland, MS' 'Orem, UT'
#  'Madrid, Spain' 'Nashua, NH' 'Towson, MD' 'Basel, Switzerland'
#  'Palm Beach, FL' 'Overland Park, KS' 'Trumbull, CT' 'Upland, CA'
#  'Stans, Switzerland' 'Pearland, TX' 'Lynbrook, NY' 'Roswell, GA'
#  'The Woodlands, TX' 'Wiesbaden, Germany' 'West Chester, PA'
#  'Newport Beach, CA' 'Pasadena, TX' 'College Station, TX'
#  'Amsterdam, Netherlands' 'Decatur, AL' 'Cumming, GA' 'Greenville, SC'
#  'Orlando, FL' 'Lake Jackson, TX' 'Galveston, TX' 'Scottsdale, AZ'
#  'Tokyo, Japan' 'Chandler, AZ' 'Princeton Junction, NJ' 'Emeryville, CA'
#  'Brentwood, TN' 'Carlsbad, CA' 'Cheseaux-sur-Lausanne, Switzerland'
#  'Zurich, Switzerland' 'Gilbert, AZ' 'Malvern, PA' 'North York, Canada'
#  'Pocatello, ID' 'Erlangen, Germany' 'SUNDERLAND, United Kingdom'
#  'Sanford, VA' 'Cranbury, NJ' 'Springfield, MO' 'Olathe, KS'
#  'Moon Township, PA' 'Mesa, AZ' 'Arlington, VA' 'Nashville, TN'
#  'Wall Township, NJ' 'Sunnyvale, CA' 'South Holland, IL' 'Harrison, NJ'
#  'Altamonte Springs, FL' 'Vienna, VA' 'Wayne, PA' 'Marlborough, MA'
#  'Herndon, VA' 'Honolulu, HI' 'Munich, Germany' 'Aachen, Germany'
#  'Eindhoven, Netherlands' 'Edmonton, Canada' 'South Portland, ME'
#  'Reno, NV' 'Chantilly, VA' 'Sanford, FL' 'Ontario, CA' 'Red Bank, NJ'
#  'Radnor, PA' 'Trenton, NJ' 'Blue Bell, PA' 'Exton, PA' 'Camden, NJ'
#  'Aurora, CO' 'Bala Cynwyd, PA' 'Rochester, MN' 'West Chester, OH'
#  'Newtown, PA' 'Horsham, PA' 'Brentford, United Kingdom'
#  'Abingdon, United Kingdom' 'New Brunswick, NJ' 'Merion Station, PA'
#  'Broomall, PA' 'Fort Washington, PA' 'Wyomissing, PA'
#  'East Brunswick, NJ' 'Virginia Beach, VA' 'Conshohocken, PA'
#  'Nottingham, United Kingdom' 'Bloomfield Hills, MI' 'Hunt Valley, MD'
#  'Warrington, United Kingdom' 'West Conshohocken, PA'
#  'Philadelphia, PA (US), PA' 'Shanghai, China' 'Phila, PA'
#  'Ruislip, United Kingdom' 'Whippany, NJ' 'Audubon, PA' 'Branford, CT'
#  'Mount Laurel, NJ' 'Elverson, PA' 'Fort Mill, SC' 'Durham, NC'
#  'Lexington, MA' 'Holmdel, NJ' 'Farmington, CT' 'West Berlin, NJ'
#  'La Hulpe, Belgium' 'MalmÃ¶, Sweden' 'Bristol, PA' 'Great Neck, NY'
#  'Bala-Cynwyd, PA' 'Noida, India' 'BENGALURU, India'
#  'Plymouth Meeting, PA' 'Basingstoke, United Kingdom' 'Kenilworth, NJ'
#  'Burnaby, Canada' 'Berkeley Heights, NJ' 'Pennsauken, NJ'
#  'East Windsor, NJ' 'Doylestown, PA' 'Hatfield, United Kingdom'
#  'Rockville, MD' 'Gibbstown, NJ' "Chignolo d'Isola, Italy" 'Sparta, NJ'
#  'Newark, CA' 'Northborough, MA' 'Bryn Mawr, PA' 'Ronkonkoma, NY'
#  'Mumbai, India' 'Plantation, FL' 'Annapolis, MD' 'Kodiak, AK'
#  'Westchester, IL' 'Tysons, VA' 'Northville, MI' 'Eden Prairie, MN'
#  'Albuquerque, NM' 'Newport News, VA' 'Rusk, TX'
#  'Wright Patterson AFB, OH' 'Catoosa, OK' 'San Marcos, CA (US), CA'
#  'BRASILIA, Brazil' 'Falls Church, VA' 'Poway, CA' 'Abbott Park, IL'
#  'Gaithersburg, MD' 'La Jolla, CA' 'Mechanicsburg, PA'
#  'Aberdeen, United Kingdom' 'California, MD' 'Beijing, China'
#  'Kalispell, MT' 'Valparaiso, IN' 'Hagerstown, MD' 'Franklin Lakes, NJ'
#  'Fenton, MI' 'Milpitas, CA' 'Las Vegas, NV' 'Veldhoven, Netherlands'
#  'Millbrae, CA' 'Germantown, MD' 'Suwon, South Korea' 'Carmel, IN'
#  'Ridgefield Park, NJ' 'Chesterfield, MO' 'OSAKA, Japan' 'Willowbrook, IL'
#  'Bannockburn, IL' 'Saint-Prex, Switzerland' 'Allen, TX' 'Richardson, TX'
#  'Bangalore, India' 'Grapevine, TX' 'Grand Prairie, TX'
#  'Conflans-Sainte-Honorine, France' 'Bezons, France' 'Cary, NC'
#  'Tifton, GA' 'Noida, UP' 'West Des Moines, IA' 'Nokia, Finland'
#  'Frisco, TX' 'Yakima, WA' 'Bloomington, IL' 'Farmers Branch, TX'
#  'Santa Ana, CA' 'Fort Worth, TX' 'Arlington, TX' 'Waukee, IA'
#  'Richmond, VA' 'Boca Raton, FL' 'Fresno, CA' 'Farmington Hills, MI'
#  'Flower Mound, TX' 'Austell, GA' 'Garden Grove, CA' 'Glendale, AZ'
#  'Sugar Land, TX' 'Rock Hill, SC' 'Annapolis Junction, MD' 'Ferris, TX'
#  'Southlake, TX' 'Ann Arbor, MI' 'Foothill Ranch, CA' 'Burlington, MA'
#  'Argyle, TX' 'HÃ\xa0 Ná»\x99i, Vietnam' 'McKinney, TX' 'Hampton, VA'
#  'Addison, TX' 'Hellerup, Denmark' 'Florham Park, NJ' 'Melbourne, FL'
#  'Dover, DE' 'Elk Grove Village, IL' 'Greenwood Village, CO'
#  'Billerica, MA' 'Wilsonville, OR' 'Santa Cruz, CA' 'Saint Petersburg, FL'
#  'Union City, CA' 'Laguna Beach, CA' 'Plymouth, MI' 'Walldorf, Germany'
#  'Livermore, CA' 'Purchase, NY' 'Latina, Italy' 'Stanford, CA'
#  'Sierra Vista, AZ' 'Hoffman Estates, IL' 'Vancouver, Canada'
#  'Oklahoma City, OK' 'Gottingen, Germany' 'Campbell, CA' 'Boise, ID'
#  'Cambridge, MA' 'San Ramon, CA' 'Los Altos, CA' 'BrasÃ\xadlia, Brazil'
#  'Bentonville, AR' 'Morristown, NJ' 'Lombard, IL' 'Short Hills, NJ'
#  'Croydon, United Kingdom' 'Cedar Falls, IA' 'Redmond, WA' 'Linthicum, MD'
#  'Charleston, SC' 'Lawrence, MA' 'Bad Homburg vor der Hohe, Germany'
#  'Mount Pleasant, SC' 'Nicosia, Cyprus' 'Allegan, MI' 'Yardley, PA'
#  'Old Greenwich, CT' 'Carpinteria, CA' 'Rockaway, NJ' 'Cedar Park, TX'
#  'Hoover, AL' 'Gainesville, VA' 'Macquarie Park, Australia'
#  'Morrisville, NC' 'Saint Petersburg Beach, FL' 'Melville, NY'
#  'Alexandria, VA' 'Round Rock, TX' 'Torrance, CA'
#  'Newcastle upon Tyne, United Kingdom' 'Natick, MA' 'Albany, NY'
#  'Dulles, VA' 'Eclepens, Switzerland' 'Des Moines, IA' 'Tucker, GA'
#  'Tarrytown, NY' 'Hercules, CA' 'CIUDAD DE MEXICO, Mexico'
#  'Providence, RI' 'Arvada, CO' 'Omaha, NE' 'Winnebago, NE' 'Tulsa, OK'
#  'Leesburg, VA' 'Portsmouth, NH' 'Framingham, MA' 'Marysville, OH'
#  'College Park, MD' 'Broadview Heights, OH' 'New Albany, OH'
#  'Bonn, Germany' 'Hilden, Germany' 'Brussel, Belgium' 'Helmetta, NJ'
#  'Old Bridge, NJ' 'Beavercreek, OH' 'Teaneck, NJ' 'Gahanna, OH'
#  'Andover, MA']
# Column 'Size' has 9 unique value(s): ['501 to 1000 employees' '1001 to 5000 employees' '1 to 50 employees'
#  '201 to 500 employees' '51 to 200 employees' '10000+ employees'
#  '5001 to 10000 employees' 'Unknown' '-1']
# Column 'Founded' has 173 unique value(s): [2007 2008   -1 2019 1985 1993 2018 2000 2014 2011 1999 2001 1998 2005
#  1943 2012 1923 2003 2002 2015 2006 2010 1853 1990 1914 2013 2004 1799
#  1935 1995 1994 1988 1917 1947 1981 1940 1841 2017 1896 2009 1898 1968
#  1862 1934 1992 2016 1984 1987 1966 1976 1871 1625 1997 1967 1948 1913
#  1989 1893 1904 1911 1961 1806 1969 1945 1784 1857 1971 1852 1922 1851
#  1956 1906 1973 1960 1975 1982 1996 1931 1986 1902 1909 1880 1946 1970
#  1979 1977 1965 1954 1850 1980 1919 1983 1888 1978 1872 1831 1936 1939
#  1937 1928 1991 1929 1944 1901 1974 1925 1817 1963 1894 1890 1882 1892
#  1908 1926 1883 1845 1849 1918 1900 1889 1837 1930 1877 1910 1962 1955
#  1897 1949 1972 1941 1957 1924 1891 1864 1951 1847 1775 1843 1855 1740
#  1792 1830 1887 1682 1881 1824 1916 1812 1905 1953 1876 1848 1858 1958
#  1938 1868 1781 1895 1869 1921 2020 1865 1933 1907 1927 1950 1952 1870
#  1912 1920 1932 1803 1866]
# Column 'Type of ownership' has 15 unique value(s): ['Company - Private' 'Unknown' 'Company - Public' 'Nonprofit Organization'
#  '-1' 'Government' 'Hospital' 'Self-employed'
#  'Subsidiary or Business Segment' 'Contract' 'School / School District'
#  'Private Practice / Firm' 'College / University' 'Franchise'
#  'Other Organization']
# Column 'Industry' has 96 unique value(s): ['Travel Agencies' 'Health, Beauty, & Fitness' '-1' 'Internet'
#  'Advertising & Marketing' 'Insurance Carriers'
#  'Investment Banking & Asset Management'
#  'Enterprise Software & Network Solutions' 'Other Retail Stores'
#  'Consulting' 'Research & Development'
#  'Motion Picture Production & Distribution' 'Brokerage Services'
#  'IT Services' 'Computer Hardware & Software' 'Security Services'
#  'Casual Restaurants' 'Food & Beverage Stores' 'Food Production'
#  'Health Fundraising Organizations' 'Home Furniture & Housewares Stores'
#  'Financial Analytics & Research' 'Education Training Services' 'Lending'
#  'Social Assistance' 'Publishing' 'Federal Agencies'
#  'Health Care Services & Hospitals' 'Oil & Gas Exploration & Production'
#  'Staffing & Outsourcing' 'Venture Capital & Private Equity'
#  'Building & Personnel Services' 'Video Games' 'Accounting'
#  'Consumer Product Rental' 'Food & Beverage Manufacturing' 'Wholesale'
#  'Banks & Credit Unions' 'Insurance Agencies & Brokerages'
#  'Municipal Governments' 'Real Estate' 'Biotech & Pharmaceuticals'
#  'Commercial Equipment Rental' 'Consumer Products Manufacturing'
#  'Sports & Recreation' 'Stock Exchanges' 'TV Broadcast & Cable Networks'
#  'Department, Clothing, & Shoe Stores' 'Aerospace & Defense' 'Energy'
#  'Construction' 'Logistics & Supply Chain'
#  'Consumer Electronics & Appliances Stores' 'Transportation Management'
#  'Colleges & Universities' 'Architectural & Engineering Services'
#  'Beauty & Personal Accessories Stores' 'Grantmaking Foundations'
#  'Industrial Manufacturing' 'Financial Transaction Processing'
#  'Electrical & Electronic Manufacturing' 'Legal' 'Farm Support Services'
#  'Transportation Equipment Manufacturing'
#  'Cable, Internet & Telephone Providers' 'K-12 Education' 'News Outlet'
#  'Cruise Ships' 'Chemical Manufacturing' 'Membership Organizations'
#  'Oil & Gas Services' 'Utilities' 'Telecommunications Services'
#  'Health Care Products Manufacturing' 'Sporting Goods Stores'
#  'Automotive Parts & Accessories Stores'
#  'Telecommunications Manufacturing' 'Gas Stations'
#  'Pet & Pet Supplies Stores' 'Trucking' 'State & Regional Agencies'
#  'Vehicle Dealers' 'Truck Rental & Leasing' 'Gambling' 'Metals Brokers'
#  'Express Delivery Services' 'Radio' 'Grocery Stores & Supermarkets'
#  'Museums, Zoos & Amusement Parks' 'Audiovisual'
#  'Fast-Food & Quick-Service Restaurants' 'Shipping'
#  'Religious Organizations' 'Convenience Stores & Truck Stops'
#  'Self-Storage Services' 'Auto Repair & Maintenance']
# Column 'Sector' has 26 unique value(s): ['Travel & Tourism' 'Consumer Services' '-1' 'Information Technology'
#  'Business Services' 'Insurance' 'Finance' 'Retail' 'Media'
#  'Restaurants, Bars & Food Services' 'Agriculture & Forestry' 'Non-Profit'
#  'Education' 'Government' 'Health Care' 'Oil, Gas, Energy & Utilities'
#  'Accounting & Legal' 'Manufacturing' 'Real Estate'
#  'Biotech & Pharmaceuticals' 'Arts, Entertainment & Recreation'
#  'Aerospace & Defense' 'Construction, Repair & Maintenance'
#  'Transportation & Logistics' 'Telecommunications' 'Mining & Metals']
# Column 'Revenue' has 14 unique value(s): ['Unknown / Non-Applicable' '$100 to $500 million (USD)'
#  '$500 million to $1 billion (USD)' '$10+ billion (USD)'
#  '$25 to $50 million (USD)' '$1 to $5 million (USD)'
#  '$5 to $10 billion (USD)' '-1' '$5 to $10 million (USD)'
#  '$50 to $100 million (USD)' '$1 to $2 billion (USD)'
#  '$2 to $5 billion (USD)' 'Less than $1 million (USD)'
#  '$10 to $25 million (USD)']
# Column 'Competitors' has 422 unique value(s): ['-1' 'Zocdoc, Healthgrades' 'BBDO, Grey Group, Droga5'
#  'Colony Specialty, Markel, RLI'
#  'Crossix Solutions Inc., AppNexus, The Trade Desk' 'Oracle'
#  'Commerce Signals, Cardlytics, Yodlee'
#  'Airbnb, Warby Parker, Kickstarter'
#  'McKinsey & Company, Accenture, Deloitte'
#  'News Corp, WarnerMedia, NBCUniversal' 'GoDaddy' 'Virtu Financial'
#  'Travelers, Chubb, Crum & Forster' 'Google, Microsoft, Apple'
#  'Advisory Board, Booz Allen Hamilton, McKinsey & Company' 'Amazon, Apple'
#  'Google, Microsoft, Walmart'
#  'Renaissance Technologies LLC, Two Sigma, AQR Capital Management'
#  'SoFi, LendingClub, Freedom Financial Network'
#  'Collabera, Mitchell Martin, The Judge Group'
#  'Brightedge Technologies, Moz, seoClarity'
#  'Economist Group, Wall Street Journal' 'Microsoft, Apple, Facebook'
#  'Oracle, Salesforce, 24/7 Real Media'
#  'Google, Goldman Sachs, Thomson Reuters'
#  'NewYork-Presbyterian Hospital, Northwell Health'
#  'Capri Holdings, LVMH, Ralph Lauren' 'Thomson Reuters, Hearst, Pearson'
#  'Infosys, Wipro, Tata Consultancy Services' 'DoorDash'
#  'National Debt Relief, Freedom Financial Network'
#  'Metis, General Assembly' 'Boston Consulting Group'
#  'Atos, Hewlett Packard Enterprise | HPE, IBM' 'Criteo, AppNexus, dataxu'
#  'J.P. Morgan, Wells Fargo, McKinsey & Company'
#  'DoubleClick, Specific Media, Collective' 'Sinai Health System'
#  'Aon, Accenture' 'Google, SAP, Accenture' 'Hired, Indeed, AngelList'
#  'Roche, GlaxoSmithKline, Novartis'
#  'EmblemHealth, UnitedHealth Group, Aetna' 'Signifyd, Forter'
#  'Amazon, Accenture, Microsoft' 'Edelman, Weber Shandwick, Porter Novelli'
#  'Cigna, Aetna, UnitedHealth Group' 'Sony, LG Electronics, Nokia' 'Humana'
#  'Activision Blizzard, Electronic Arts'
#  'Jibe, Phenom People, SmashFly Technologies'
#  "S&P Global Ratings, Moody's Corporation, Fitch Ratings"
#  'Goldman Sachs, Commonwealth Bank of Australia, Deutsche Bank'
#  'State Street, Northern Trust, BlackRock' 'New York Life, Prudential'
#  'DraftKings' 'ICE, CME Group, Cboe Global Markets' 'GitHub' 'Trintech'
#  'Netflix, Amazon, Apple'
#  'Blizzard Entertainment, Electronic Arts, Riot Games'
#  'OpenSymmetry, Perficient, DataClarity'
#  'Riot Games, Google, Activision Blizzard' 'Adobe, Akamai, Oracle'
#  'Walt Disney Company, NBCUniversal'
#  'MD Anderson Cancer Center, Memorial Sloan Kettering, UCLA Health'
#  'Health Net, Kaiser Permanente, Molina Healthcare'
#  'Flexport, Convoy, C.H. Robinson' 'Facebook, Twitter, WhatsApp'
#  'Cerner, Epic, Athena Health Care Systems'
#  'AMPLEXOR, TransPerfect, Lionbridge'
#  'Google, Microsoft, Samsung Electronics' 'Accenture, CGI, Sopra Steria'
#  'NBCUniversal, WarnerMedia, Netflix' 'BlackRock, Nuveen, Piper Sandler'
#  'UCLA Health, City of Hope, Keck Medicine of USC' 'NBCUniversal'
#  'Activision, Riot Games, Electronic Arts' 'Robert Half, Insight Global'
#  'General Assembly, Hack Reactor, WeWork'
#  'Adecco, ManpowerGroup, Allegis Corporation'
#  'Trello, Slack, Lucid Software' 'R/GA, MRM'
#  'Chegg, Tutor.com, Smarthinking' 'Cyient'
#  'East West Bank, Bank of the West, First Republic Bank'
#  'TEKsystems, Insight Global, Accenture'
#  'Cedars-Sinai Medical Center, Loma Linda University Health, Harbor Hospital'
#  'DPR Construction, Webcor' 'FieldAware, FieldEdge, SuccessWare'
#  'Adecco, Manpower'
#  'Illumina, Thermo Fisher Scientific, Oxford Nanopore Technologies'
#  'Illumina, Agilent Technologies, Roche' 'Kforce, NTT DATA, IBM'
#  'Texas Instruments, Qualcomm' 'Experis' 'Electronic Arts, Sony, Take-Two'
#  'Procter & Gamble, NestlÃ©, Johnson & Johnson'
#  'HCA Healthcare, Dignity Health, Sutter Health'
#  'Edmunds.com, Autotrader, Cars.com'
#  'Pitney Bowes, US Postal Service, Envelope Manager Software'
#  'Microsoft, McAfee, Trend Micro'
#  'Kaiser Permanente, CVS Health, Walgreens'
#  'Blizzard Entertainment, Valve Corporation, Electronic Arts'
#  'Sutter Health, Kaiser Permanente, Tenet Healthcare'
#  'Comcast, Spectrum Comm, Windstream' 'Birchbox, ipsy, Stitch Fix'
#  'Progressive Insurance, State Farm, Allstate'
#  'Collabera, Artech Information Systems, TEKsystems' 'AgilOne, IBM'
#  'Randstad US, Robert Half, Allegis Group' 'Top Hat, Flocabulary'
#  'PRA Health Sciences, PPD, IQVIA'
#  'AQR Capital Management, Citadel, Two Sigma'
#  'J.P. Morgan, Bank of America' 'Granular, Intuit, John Deere'
#  'WCI Consulting, PwC'
#  'Soros Fund Management, D. E. Shaw & Co. - Investment Firm, Fortress Investment Group'
#  'PepsiCo, Anheuser-Busch InBev, MondelÄ\x93z International'
#  'eHealth, Anthem' 'Northwestern Mutual, State Farm'
#  'Anheuser-Busch InBev, The Boston Beer Company' 'Oracle, Accenture'
#  'Dropbox, NetDocuments, OpenText'
#  'Oak Ridge National Laboratory, Lawrence Livermore National Laboratory, Fermilab'
#  'John Deere, Komatsu, CNH Industrial' 'CIBC, RBC, TD'
#  'Walmart, Walgreens, Express Scripts'
#  'Redwood Logistics, Coyote Logistics, Echo Global Logistics'
#  'Intertek, SGS, Bureau Veritas' 'Optiver, Citadel, DRW'
#  'J.P. Morgan, Bank of America, U.S. Bank'
#  'Susquehanna International Group (SIG), Jane Street, Optiver'
#  'Thomson Reuters, FactSet, Bloomberg L.P.'
#  'Mercer, Willis Towers Watson, Marsh & McLennan Companies'
#  'United Natural Foods, US Foods, DPI Specialty Foods'
#  'Capgemini, Slalom, Accenture' 'Ameren, PPL, Southern Company'
#  'Jump Trading, Tower Research Capital LLC, Hudson River Trading'
#  'Nielsen, Kantar, IRI' 'Meteorix, OneSource Virtual, DayNine Consulting'
#  'Aetna, Humana, WellPoint' 'Medpace, INC Research, inVentiv Health'
#  'Flagship Cruises & Events, New York Water Taxi, Red and White Fleet'
#  'Boston Consulting Group, Bain & Company, Strategy&'
#  'Cognizant Technology Solutions, Infosys, Wipro'
#  'BMC Software, CA Technologies, Salesforce'
#  'Artech Information Systems, Mindlance, Tech Mahindra'
#  'Kearney, AlixPartners, Hitachi Consulting'
#  'Accenture, Deloitte, Avanade' 'Slickdeals, RetailMeNot'
#  'Beacon Hill Staffing Group, PageGroup, Solomon Page'
#  'Mediaocean, The Trade Desk, MediaMath'
#  'Resurrection Health Care, UChicago Medicine'
#  'Kforce, Insight Global, Volt Consulting Group'
#  'CDW, PCM, SHI International' 'Merkle'
#  'General Mills, Kellogg Company, Kraft Heinz Company'
#  'Randstad US, Labor Finders' 'Sysco, Golden State Foods, Anderson-DuBose'
#  'Kforce, PageGroup, Robert Half'
#  'Anheuser-Busch InBev, The Boston Beer Company, Constellation Brands'
#  'CBRE, Cushman & Wakefield' 'Deloitte, KPMG, PwC'
#  'ComforceHealth, TEKsystems, Allegis Group'
#  'Accenture, West Monroe, Slalom'
#  'Straight North, Digital Third Coast, Rise Interactive'
#  'Rush University Medical Center, UChicago Medicine' 'UnityPoint Health'
#  'The Judge Group, Addison Group, PageGroup' 'Blue Yonder, SAP, NCR'
#  'Interpublic Group, Omnicom, WPP' 'Weatherford, Schlumberger'
#  'Performance Food Group'
#  'Slalom, Cognizant Technology Solutions, Deloitte'
#  'Schlumberger, Halliburton, Cameron'
#  'WesternGeco, Petroleum Geo-Services, TGS'
#  'Diplomat, Nimble Pharmacy, CVS Health'
#  'Converge, Future Electronics, Advanced MP Technology'
#  'Zurich Insurance, AXA XL, Allianz' 'Pioneer, Syngenta'
#  'World Wide Technology, Presidio, Optiv' 'NTT DATA, itelligence, Infosys'
#  'Vanguard, BlackRock, Fidelity Investments'
#  'Carr Riggs & Ingram, Cherry Bekaert, LBMC'
#  'American Tower, SBA Communications, TowerCo LLC'
#  'Booz Allen Hamilton, Abt Associates, Oliver Wyman'
#  'Transnational Foods, One Source Distributors' 'Perrigo, Covance, DSM'
#  'CH2M, AECOM, Gannett Fleming' 'Jacobs, Stantec, AMEC'
#  'Shamrock Trading Corporation, FREIGHTQUOTE, Netsmart'
#  'Honeywell, Invensys'
#  'Cloudreach, CenturyLink, Cloud Technology Partners' 'GE'
#  "MD Anderson Cancer Center, Memorial Hermann Health System, Texas Children's Hospital"
#  'INVISTA' 'Deloitte, KPMG' 'Thomson Reuters, International Data Group'
#  'Big O Tires, Les Schwab Tire Centers, Pep Boys'
#  'GEICO, MetLife, State Farm'
#  'Compass Lexecon, Navigant, Charles River Associates'
#  'DP Electric, Helix Electric, Wilson Electric'
#  'MATRIX Resources, The Insource Group, TEKsystems'
#  'Snapfish, Vistaprint, Minted' 'Harris, Gogo, Inmarsat'
#  'TEKsystems, Aerotek'
#  'Nationstar Mortgage, Caliber Funding, Quicken Loans'
#  'Charles Schwab, Fidelity Investments, Edward Jones'
#  'GE Healthcare, Roche'
#  "Whole Foods Market, Market Street United, Trader Joe's"
#  'Square, Amazon, Apple' 'Advance Auto Parts, AutoZone, NAPA Auto Parts'
#  'Petco, Walmart, Target' 'Kleinfelder, PSI'
#  'Allstate, Prudential, State Farm' 'ManTech, Booz Allen Hamilton, Leidos'
#  'Banner Health' 'First Republic Bank, Comerica'
#  'Persistent Systems (India), GlobalLogic, Synechron' 'LabCorp, Theranos'
#  'Adecco, Kforce'
#  'Progressive Insurance, State Farm, Farmers Insurance Group'
#  'NEXTGEN GLOBAL RESOURCES, Wavsys, TEKsystems' 'GE, ABB, Philips'
#  'CarMax, AutoNation, Sonic Automotive'
#  'Cognizant Technology Solutions, EY, McKinsey & Company'
#  'Kforce, Mitchell Martin, Insight Global'
#  'Amazon, PwC, McKinsey & Company' 'Covance, ICON' 'AT&T, Verizon'
#  'Harvard University, Yale University, Princeton University'
#  'CSC, OpSec Security Group' 'Randstad, Kelly'
#  'Pfizer, AstraZeneca, Merck' 'Abbott, Novartis, Covidien'
#  'RELX, Wolters Kluwer, Informa'
#  'Caesars Entertainment, MGM Resorts International'
#  'Cortexica Vision Systems, Image Searcher' 'Vaptech'
#  'The Judge Group, Randstad, Kforce'
#  'Aerotek, WinterWyman, Hollister Staffing'
#  'AbbVie, Genentech, AstraZeneca'
#  'PathFinder Staffing, Juno Search Partners, Robert Half'
#  'PPD, INC Research, PRA Health Sciences'
#  'TEKsystems, Artech Information Systems, PDS Tech'
#  'Clarivate, Springer Nature, Thomson Reuters' 'Penn Medicine'
#  'Turtle & Hughes, Synovos' 'Lockheed Martin, Northrop Grumman, Airbus'
#  'Aerotek, Kforce, Glotel' 'Genentech, Gilead Sciences'
#  'Roche, Novartis, GlaxoSmithKline'
#  'Clinical Professionals, Real Staffing, NonStop Consulting'
#  'ZS Associates, Cognizant Technology Solutions, IQVIA'
#  'Boeing, Northrop Grumman, Raytheon Technologies'
#  'TEKsystems, CGI, SDLC Partners'
#  'TEKsystems, Collabera, Artech Information Systems'
#  'Apex Systems, Kforce, Robert Half'
#  "Penn Medicine, Thomas Jefferson University Hospital, Children's Hospital of Philadelphia"
#  'Los Alamos National Laboratory, Battelle, SRI International'
#  'Perrigo, GNC (PA), Schiff Nutrition International'
#  'Accenture, IBM, Infosys' 'Booz Allen Hamilton, Deloitte, ERPi'
#  'CUMULUS MEDIA, Entercom, Cox Media Group'
#  'Cognizant Technology Solutions, Accenture, IBM'
#  'Phillips 66, Marathon Petroleum, HollyFrontier Corporation'
#  'Booz Allen Hamilton, Noblis, Deloitte'
#  'General Dynamics, Lockheed Martin'
#  'Infosys, Tata Consultancy Services, Wipro'
#  'BAE Systems USA, CACI International, General Dynamics Information Technology'
#  'PetSmart, Walmart, Costco Wholesale' 'SAIC, Leidos, Northrop Grumman'
#  'CSC, ManTech, SAIC' 'Thermo Fisher Scientific, Roche' 'PRA Group'
#  'SmartBug Media, Kobe Digital (US), Firesnap' 'Medtronic, Roche'
#  'Accenture, Deloitte, PwC' 'Biogen' 'Philips, Drive DeVilbiss Healthcare'
#  'Liberty Mutual Insurance, EMPLOYERS, Travelers'
#  'Northrop Grumman, Raytheon Technologies, Lockheed Martin'
#  'Sharp HealthCare, Scripps Health' 'PRA Group, PRA Group (Canada)'
#  'Battelle, SRI International, MITRE'
#  'Intel Corporation, MediaTek, Broadcom'
#  'Kaiser Permanente, Scripps Health, UC San Diego Health'
#  'Cornerstone OnDemand, Blackboard' 'Battelle, General Atomics, SAIC'
#  'Northrop Grumman, General Atomics, Raytheon Technologies'
#  'Abbott, Siemens, Baxter' 'Applied Materials, KLA, Lam Research'
#  'TomTom, NETGEAR' 'BD, Abcam, Bio-Techne'
#  'RedBrick Health, Tivity Health' 'Novartis, Baxter, Pfizer'
#  'GE Healthcare, Illumina, Boston Scientific'
#  'Abbott, Roche, Thermo Fisher Scientific'
#  'ID Business Solutions, Tripos LP' 'RingCentral, Nextiva, 8x8'
#  'Automatic, Mojio, Verizon Telematics' 'Trane, Carrier, Goodman'
#  'ALDI, Tesco, Carrefour' 'IBM, Accenture, Booz Allen Hamilton'
#  'Cedar Fair, SeaWorld Parks & Entertainment, Herschend Entertainment'
#  'Tata Consultancy Services, Accenture, Cognizant Technology Solutions'
#  'J.P. Morgan, Merrill Lynch, Morgan Stanley' 'Accenture, Capgemini'
#  'projekt202, IDEO' 'McKinsey & Company, Bain & Company, Accenture'
#  'McKesson, Cardinal Health, Kinray'
#  'Ericsson-Worldwide, Huawei Technologies, Microsoft'
#  'Mu Sigma, LatentView Analytics, Fractal' 'GATX, BNSF Railway'
#  "Nordstrom, Saks Fifth Avenue, Bloomingdale's"
#  'Berkshire Hathaway, Progressive Insurance, Allstate'
#  'ADT Security Services, Protection 1' 'Pratt & Whitney, Lockheed Martin'
#  'Raymond James Financial'
#  'FDIC, Office of the Comptroller of the Currency, SEC'
#  'Hess Corporation, QuikTrip, Couche-Tard' 'Yardi Systems, AppFolio'
#  'Capgemini, Accenture, Deloitte'
#  'Edelman, Burson-Marsteller, Weber Shandwick'
#  'Alliance Residential, Wood Partners, Trammell Crow Residential'
#  'Arena, HCL Technologies, PTC' 'Technosoft Inc, Deegit'
#  'GM Financial, Ally Financial, Credit Acceptance'
#  'SPX, Flowserve, Robbins & Myers' 'Quicken Loans, LendingClub, SoFi'
#  'Mortgage Connect, Amrock, Title365' 'Orthofix, Stryker'
#  'Dealertrack, VinSolutions, CDK Global' 'Robert Half, Randstad US'
#  'Manpower, BravoTECH, High Profile'
#  'Salesforce, Boston Consulting Group, ZS Associates'
#  'Skyhigh Networks, Zscaler, NortonLifeLock'
#  'GE Digital, Palantir Technologies, Uptake'
#  'Cadence Design Systems, Synopsys, Altium Limited'
#  'Seagate Technology, Toshiba' 'Foxconn, Plexus' 'Lemonade, Metromile'
#  'Skytron, STERIS, Hill-Rom' 'Salesforce, Oracle, Microsoft'
#  'Los Alamos National Laboratory, NASA Jet Propulsion Laboratory, Sandia National Laboratories'
#  'Facebook, Snap, TikTok' 'Genomic Health, 23andMe, Illumina'
#  'The Climate Corp, CNH Industrial, C.A.T.' 'AppLovin, Drawbridge'
#  'Amazon, Best Buy, Apple' 'Infosys, Accenture, Capgemini'
#  'Chegg, StudyBlue' 'ObserveIT, Forcepoint'
#  'Square, Early Warning Services'
#  'AIR Worldwide, EQECAT, Verisk Analytics'
#  'Bill & Melinda Gates Foundation' 'Facebook, Google, Pinterest'
#  'Novartis, AstraZeneca, Siemens Healthineers'
#  'InsWeb, Insure.com, Answer Financial'
#  'Reynolds and Reynolds, Cox Automotive, Dealer.com'
#  'Milestone Technologies, Taos, GDH Consulting'
#  'SpotX, FreeWheel, TubeMogul' 'Qualcomm, Intel Corporation, AMD'
#  'Audi, BMW, Mercedes-Benz International'
#  'Samsung Electronics, SK hynix, Toshiba'
#  'Mirror Image Internet, Limelight Networks'
#  'STMicroelectronics, Fairchild Semiconductor, Infineon Technologies'
#  'TEKsystems, Akraya, Intelliswift' 'Waymo'
#  'Los Alamos National Laboratory, Lawrence Livermore National Laboratory'
#  'Ross Stores, American Eagle Outfitters'
#  'Target, Costco Wholesale, Amazon' 'Infosys, Daz Systems inc'
#  'Mentor Graphics, Synopsys' 'Medtronic' 'Experian, Equifax' 'Everbridge'
#  'Atkins, Arup, CH2M' "Kroger, Safeway, Trader Joe's"
#  'Google, Amazon, Apple' 'Simply Hired, CareerBuilder, Glassdoor'
#  'Priceline.com, Booking.com, Kayak.com' 'OneSignal'
#  'Baxter, Gambro AB, Fresenius' 'SAP, Salesforce, Microsoft'
#  'Accenture, Northrop Grumman, Xerox'
#  'PayPal, American Express, Visa Inc.'
#  'Texas Instruments, Maxim Integrated, Analog Devices'
#  'Northrop Grumman, Thales, Rolls-Royce'
#  'Intel Corporation, Imagination Technologies, NXP Semiconductors'
#  'Salesforce, Localytics, Mixpanel' 'Anthem, Molina Healthcare, Humana'
#  'Zocdoc, Sapphire Digital' 'Palo Alto Networks, Tanium'
#  'Attain, Deloitte, Booz Allen Hamilton'
#  'AQR Capital Management, BlackRock, PIMCO'
#  'GLOBALFOUNDRIES, Intel Corporation, TSMC' 'Okta, Ping Identity, Oracle'
#  'Epic' 'Fidelity Investments, UBS, Morgan Stanley'
#  'Booz Allen Hamilton, CACI International' 'Agilent Technologies'
#  'McKinsey & Company, Bain & Company, Boston Consulting Group'
#  'Mindtree, Happiest Minds Technologies, Altran Americas'
#  'Nest, Siemens, ecobee' 'IBM, Apple, HP Inc.'
#  'LabCorp, Quest Diagnostics' 'UMC, TSMC' 'Target, Walmart'
#  'Thermo Fisher Scientific, Abbott, Ortho Clinical Diagnostics'
#  'Aerotek, TEKsystems, HireStrategy'
#  'Marketing Werks, GMR Marketing, Anderson Merchandisers'
#  'Elsevier, Thomson Reuters, Google' 'DSW, L Brands, Central Garden & Pet'
#  'American Eagle Outfitters, Ralph Lauren, J. Crew'
#  'Teva Pharmaceuticals, Sandoz International, Perrigo' 'AbbVie'
#  'Allstate, Nationwide, State Farm' 'TEKsystems, Kforce, Randstad US'
#  'Tata Consultancy Services, Accenture, Capgemini' 'Robert Half, Kforce']
# Column 'Easy Apply' has 2 unique value(s): ['-1' 'True']

# %% [markdown]
# # Salary By Company Size
#
# Bar Chart and Pie Chart for Salary vs Company Size
#
# Note: Does not include "Unknown" and "-1" categories

# %%
# !wget -O dsjob.csv https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryBySizeSplit.csv
df1 = pd.read_csv("dsjob.csv",encoding='latin-1')

# Categories for x-axis
categories = ['1 to 50 employees', '51 to 200 employees', '201 to 500 employees', '501 to 1000 employees',
              '1001 to 5000 employees', '5001 to 10000 employees', '10000+ employees']
new_x_labels = ['1-50', '51-200', '201-500', '501-1000', '1001-5000', '5001-10000', '10000+']

avg_min_salaries = []
avg_max_salaries = []

# Count data points in each category
counts = [df1[df1['Company Size'] == category].shape[0] for category in categories]
total = sum(counts)

for category in categories:
    category_data = df1[df1['Company Size'] == category]
    avg_min_salaries.append(category_data['Min. Salary Estimate (in thousands of $)'].mean())
    avg_max_salaries.append(category_data['Max. Salary Estimate (in thousands of $)'].mean())

# Colors for the Bar and Pie Charts
max_salary_colors = [ (0.917, 0.333, 0.271), (0.937, 0.608, 0.125), (0.929, 0.882, 0.357), (0.529, 0.737, 0.271),
                      (0.702, 0.239, 0.776), (0.596, 0.345, 0.635), (0.420, 0.357, 0.584) ]

min_salary_colors = [clrs.to_rgb(color) for color in max_salary_colors]

# Make min. bars lighter
lighten_factor = 0.6
for i in range(len(min_salary_colors)):
    r, g, b = min_salary_colors[i]
    min_salary_colors[i] = (r + (1 - r) * lighten_factor, g + (1 - g) * lighten_factor, b + (1 - b) * lighten_factor)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar Chart
width = 0.45
x = range(len(categories))

bars = []
legend_colors = []
for i in range(len(categories)):
    bar = ax1.bar(i, avg_min_salaries[i], width, label='Min. Salary', color=min_salary_colors[i])
    bars.append(bar)
    bar = ax1.bar(i + width, avg_max_salaries[i], width, label='Max. Salary', color=max_salary_colors[i])
    legend_colors.append(plt.Rectangle((0, 0), 1, 1, color=max_salary_colors[i]))

ax1.set_title("Average Salary vs Company Size")
ax1.set_xlabel('Company Size (number of Employees)')
ax1.set_ylabel('Average Salary Estimate (in thousands of $)')
ax1.set_xticks([i + width/2 for i in x])
ax1.set_xticklabels(new_x_labels)
ax1.tick_params(axis='x', rotation=45)
ax1.legend(legend_colors, categories, loc='center left', bbox_to_anchor=(1, 0.5))

# Pie chart
ax2.pie(counts, labels=new_x_labels, autopct='%1.1f%%', startangle=90, colors=max_salary_colors)
ax2.set_title('Distribution of the Number of Companies')
ax2.text(0.5, -0.15, f'n = {total}', ha='center', va='center', transform=ax2.transAxes, fontsize=10, bbox=dict(facecolor='none', edgecolor='black'))

plt.tight_layout()
plt.show()
# Out:
# --2023-12-04 00:45:43--  https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryBySizeSplit.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100053 (98K) [text/plain]
# Saving to: ‘dsjob.csv’
#
# dsjob.csv           100%[===================>]  97.71K  --.-KB/s    in 0.03s
#
# 2023-12-04 00:45:43 (3.58 MB/s) - ‘dsjob.csv’ saved [100053/100053]

# %% [markdown]
# #Highest and Lowest Salary By Company Size
#
# Bar Chart and Pie Chart for Salary vs Company Size
#
# Note: Does not include "Unknown" and "-1" categories

# %%
# !wget -O dsjob4.csv https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryBySizeSplit.csv
df5 = pd.read_csv("dsjob4.csv", encoding='latin-1')

# Categories for x-axis
categories = ['1 to 50 employees', '51 to 200 employees', '201 to 500 employees', '501 to 1000 employees',
              '1001 to 5000 employees', '5001 to 10000 employees', '10000+ employees']
new_x_labels = ['1-50', '51-200', '201-500', '501-1000', '1001-5000', '5001-10000', '10000+']

# Quantiles for top 10% and bottom 10%
quantiles_min = []
quantiles_max = []
counts = []
total = 0

for category in categories:
    category_data = df5[df5['Company Size'] == category]
    total += category_data.shape[0]
    quantile_min = category_data['Min. Salary Estimate (in thousands of $)'].quantile(0.1)
    quantile_max = category_data['Max. Salary Estimate (in thousands of $)'].quantile(0.9)
    quantiles_min.append(quantile_min)
    quantiles_max.append(quantile_max)
    counts.append(category_data[(category_data['Min. Salary Estimate (in thousands of $)'] <= quantile_min) |
                                (category_data['Max. Salary Estimate (in thousands of $)'] >= quantile_max)].shape[0])

# Colors for the Bar and Pie Charts
max_salary_colors = [(0.917, 0.333, 0.271), (0.937, 0.608, 0.125), (0.929, 0.882, 0.357), (0.529, 0.737, 0.271),
                     (0.702, 0.239, 0.776), (0.596, 0.345, 0.635), (0.420, 0.357, 0.584)]

min_salary_colors = [clrs.to_rgb(color) for color in max_salary_colors]

# Make min. bars lighter
lighten_factor = 0.6
min_salary_colors_rgb = [
    (r + (1 - r) * lighten_factor, g + (1 - g) * lighten_factor, b + (1 - b) * lighten_factor)
    for r, g, b in min_salary_colors]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar Chart
width = 0.45
x = range(len(categories))

bars_min = []
bars_max = []
legend_colors = []
for i in range(len(categories)):
    bar1 = ax1.bar(i, quantiles_min[i], width, label='10% Min. Salary', color=min_salary_colors_rgb[i])
    bars_min.append(bar1)
    bar2 = ax1.bar(i + width, quantiles_max[i], width, label='90% Max. Salary', color=max_salary_colors[i])
    bars_max.append(bar2)
    legend_colors.append(plt.Rectangle((0, 0), 1, 1, color=max_salary_colors[i]))

ax1.set_title("Salary (Min. and Max.) vs Company Size")
ax1.set_xlabel('Company Size (number of Employees)')
ax1.set_ylabel('Salary Estimate (in thousands of $)')
ax1.set_xticks([i + width / 2 for i in x])
ax1.set_xticklabels(new_x_labels)
ax1.tick_params(axis='x', rotation=45)
ax1.legend(legend_colors, categories, loc='center left', bbox_to_anchor=(1, 0.5))

# Pie chart
ax2.pie(counts, labels=new_x_labels, autopct='%1.1f%%', startangle=90, colors=max_salary_colors)
ax2.set_title('Distribution of the Number of Companies')
ax2.text(0.5, -0.15, f'n = {sum(counts)}', ha='center', va='center', transform=ax2.transAxes, fontsize=10,
         bbox=dict(facecolor='none', edgecolor='black'))

plt.tight_layout()
plt.show()
# Out:
# --2023-12-04 00:45:44--  https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryBySizeSplit.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100053 (98K) [text/plain]
# Saving to: ‘dsjob4.csv’
#
# dsjob4.csv          100%[===================>]  97.71K  --.-KB/s    in 0.03s
#
# 2023-12-04 00:45:44 (3.39 MB/s) - ‘dsjob4.csv’ saved [100053/100053]

# %% [markdown]
# # Avg Min and Avg Max Salary By Experience Level
#
# Bar Chart and Pie Chart for Salary vs Experience Level
#
# Note: Ignores other job titles that *could* influence the plots

# %%
# !wget -O dsjob1.csv https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryByExperienceSplit.csv
df2 = pd.read_csv("dsjob1.csv",encoding='latin-1')

# Categories for x-axis: Account for jr and sr
categories = {
    'Junior': df2[df2['Experience Level'].str.contains('junior|jr', case=False)],
    'Senior': df2[df2['Experience Level'].str.contains('senior|sr', case=False)],
    'Manager': df2[df2['Experience Level'].str.contains('manager', case=False)],
    'Director': df2[df2['Experience Level'].str.contains('director', case=False)]
}

# Colors for the Bar and Pie Charts
category_colors_rgb = {'Junior': (0.992, 0.498, 0.435), 'Senior': (0.741, 0.494, 0.745), 'Manager': (0.745, 0.725, 0.859), 'Director': (0.545, 0.827, 0.780)}

avg_min_salaries = []
avg_max_salaries = []

for category, data in categories.items():
    avg_min_salaries.append(data['Min. Salary Estimate (in thousands of $)'].mean())
    avg_max_salaries.append(data['Max. Salary Estimate (in thousands of $)'].mean())

# Count data points in each category
counts = [len(data) for category, data in categories.items()]
total = sum(counts)

# Make min. bars lighter
lighten_factor = 0.6
min_salary_colors_rgb = {
    category: tuple((1 - lighten_factor) * val + lighten_factor for val in color)
    for category, color in category_colors_rgb.items()
}

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar chart
x = range(len(categories))
width = 0.35

bars_min = []
bars_max = []
for i, (category, color) in enumerate(zip(categories.keys(), category_colors_rgb.values())):
    bar1 = ax1.bar(i, avg_min_salaries[i], width, label='Average Min Salary', color=min_salary_colors_rgb[category])
    bar2 = ax1.bar(i + width, avg_max_salaries[i], width, label='Average Max Salary', color=color)
    bars_min.append(bar1)
    bars_max.append(bar2)

ax1.set_xlabel('Experience Level')
ax1.set_ylabel('Average Salary Estimate (in thousands of $)')
ax1.set_title('Average Salary vs Experience Level')
ax1.set_xticks([i + width / 2 for i in x])
ax1.set_xticklabels(categories.keys())
ax1.tick_params(axis='x', rotation=45)
legend_colors = [clrs.to_rgba(rgb) for rgb in category_colors_rgb.values()]
ax1.legend([bars_max[i] for i in range(len(bars_max))], categories, loc='center left', bbox_to_anchor=(1, 0.5))

# Pie chart
pie_colors = [color for _, color in category_colors_rgb.items()]
ax2.pie(counts, labels=categories.keys(), autopct='%1.1f%%', startangle=90, colors=pie_colors)
ax2.set_title('Distribution of Positions')
ax2.text(0.5, -0.15, f'n = {total}', ha='center', va='center', transform=ax2.transAxes, fontsize=10, bbox=dict(facecolor='none', edgecolor='black'))

plt.tight_layout()
plt.show()
# Out:
# --2023-12-04 00:45:45--  https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryByExperienceSplit.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27904 (27K) [text/plain]
# Saving to: ‘dsjob1.csv’
#
# dsjob1.csv          100%[===================>]  27.25K  --.-KB/s    in 0.003s
#
# 2023-12-04 00:45:45 (9.33 MB/s) - ‘dsjob1.csv’ saved [27904/27904]

# %% [markdown]
# # Highest and Lowest Salary By Experience Level
#
#
# Bar Chart and Pie Chart for Salary vs Experience Level
#
#
# Note: Ignores other job titles that *could* influence the plots

# %%
# !wget -O dsjob2.csv https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryByExperienceSplit.csv
df3 = pd.read_csv("dsjob2.csv",encoding='latin-1')

# Categories for x-axis
categories = {
    'Junior': df3[df3['Experience Level'].str.contains('junior|jr', case=False)],
    'Senior': df3[df3['Experience Level'].str.contains('senior|sr', case=False)],
    'Manager': df3[df3['Experience Level'].str.contains('manager', case=False)],
    'Director': df3[df3['Experience Level'].str.contains('director', case=False)]
}

lowest_10_percent_avg_min = []
highest_10_percent_avg_max = []

for category, data in categories.items():
    avg_min_salaries = data.groupby('Experience Level')['Min. Salary Estimate (in thousands of $)'].mean()
    avg_max_salaries = data.groupby('Experience Level')['Max. Salary Estimate (in thousands of $)'].mean()

    lowest_10_percent_avg_min.append(avg_min_salaries.sort_values().head(int(len(avg_min_salaries) * 0.1)).mean())
    highest_10_percent_avg_max.append(avg_max_salaries.sort_values(ascending=False).head(int(len(avg_max_salaries) * 0.1)).mean())

# Category colors
category_colors_rgb = { 'Junior': (0.702, 0.749, 0.819), 'Senior': (0.784, 0.396, 0.345),
                       'Manager': (0.510, 0.004, 0.041), 'Director': (0.239, 0.412, 0) }

#Count the data points
counts = [
    len(categories[category][
        (categories[category]['Min. Salary Estimate (in thousands of $)'] <= lowest_10_percent_avg_min[i]) |
        (categories[category]['Max. Salary Estimate (in thousands of $)'] >= highest_10_percent_avg_max[i])]
    )
    for i, (category, _) in enumerate(categories.items()) ]
total = sum(counts)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Bar chart and bars
x = range(len(categories))
width = 0.35

bars1 = ax1.bar(x, lowest_10_percent_avg_min, width, label='Lowest 10% Avg Min Salary',
                color=[clrs.to_rgb(rgb) for rgb in category_colors_rgb.values()])
bars2 = ax1.bar([i + width for i in x], highest_10_percent_avg_max, width, label='Highest 10% Avg Max Salary',
                color=[clrs.to_rgb(rgb) for rgb in category_colors_rgb.values()])

# Make min. bars lighter
lighten_factor = 0.5
for bar in bars1:
    r, g, b, _ = bar.get_facecolor()
    bar.set_facecolor((r + (1 - r) * lighten_factor, g + (1 - g) * lighten_factor, b + (1 - b) * lighten_factor, 1))

ax1.set_xlabel('Experience Level')
ax1.set_ylabel('Salary Estimate (in thousands of $)')
ax1.set_title('Salary (Min. and Max.) vs Experience Level')
ax1.set_xticks([i + width / 2 for i in x])
ax1.set_xticklabels(categories.keys())
ax1.tick_params(axis='x', rotation=45)
legend_colors = [clrs.to_rgba(rgb) for rgb in category_colors_rgb.values()]
ax1.legend([bars2[i] for i in range(len(bars2))], categories.keys(), loc='center left', bbox_to_anchor=(1, 0.5), labelcolor='black')

# Pie Chart
pie_colors = [clrs.to_rgba(rgb) for rgb in category_colors_rgb.values()]
ax2.pie(counts, labels=categories.keys(), autopct='%1.1f%%', startangle=90, colors=pie_colors)
ax2.set_title('Distribution of Positions')
ax2.text(0.5, -0.15, f'n = {total}', ha='center', va='center', transform=ax2.transAxes, fontsize=10, bbox=dict(facecolor='none', edgecolor='black'))

plt.tight_layout()
plt.show()
# Out:
# --2023-12-04 00:45:46--  https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/SalaryByExperienceSplit.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27904 (27K) [text/plain]
# Saving to: ‘dsjob2.csv’
#
# dsjob2.csv          100%[===================>]  27.25K  --.-KB/s    in 0.003s
#
# 2023-12-04 00:45:46 (8.84 MB/s) - ‘dsjob2.csv’ saved [27904/27904]

# %% [markdown]
# # Industry Type By Company Rating
#
#
# Bar Chart and Pie Chart for Industry Type vs Company Rating
#
#
# Note: Ignores values of -1 and records missing values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# !wget -O dsjob3.csv https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/IndustryByRating.csv
df4 = pd.read_csv("dsjob3.csv", encoding='latin-1')

# Group by 'Industry Type' and calculate the average rating for each industry type
df4['Industry Type'] = df4['Industry Type'].replace('Oil - Gas - Energy & Utilities', 'Oil, Gas, Energy & Utilities')
avg_ratings = df4.groupby('Industry Type')['Company Rating'].mean()

# Colors for bars
bar_colors = [(0.298, 0.447, 0.690), (0.867, 0.518, 0.322), (0.333, 0.659, 0.408), (0.768, 0.305, 0.321), (0.505, 0.447, 0.698),
              (0.576, 0.470, 0.376), (0.854, 0.545, 0.764), (0.549, 0.549, 0.549), (0.800, 0.725, 0.454), (0.392, 0.710, 0.803)]

# Count the data points
data_points = df4['Industry Type'].value_counts()
percentages = data_points / data_points.sum() * 100

# Filter out percentages smaller than 3% - For "Other" category
small_percentages = percentages[percentages < 3]
other_percentage = small_percentages.sum()
if len(small_percentages) > 0:
    small_indices = small_percentages.index
    data_points['Other'] = data_points[small_indices].sum()
    data_points.drop(small_indices, inplace=True)

# Recalculate percentages after aggregating "Other"
percentages = data_points / data_points.sum() * 100

# Plot Bar Chart
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

avg_ratings.plot(kind='barh', color=bar_colors, ax=ax1)
ax1.set_xlabel('Average Company Rating')
ax1.set_ylabel('Industry Type')
ax1.set_title('Average Company Rating by Industry Type')
ax1.set_xticks([0, 1, 2, 3, 4, 5])
ax1.grid(axis='x')

# Colors for Pie Chart
filtered_bar_colors = bar_colors[:len(data_points)]
pie_colors = filtered_bar_colors + [(0.7, 0.7, 0.7)]  # Gray color for "Other"

# Plot Pie Chart
wedges, texts, autotexts = ax2.pie(data_points, labels=data_points.index, autopct='%1.1f%%', colors=pie_colors)
ax2.set_title('Data Points by Industry Type')

# Calculate n
total_data_points = sum(data_points)
total_text = f"n = {total_data_points}"
ax2.text(0.5, -0.15, total_text, ha='center', va='center', transform=ax2.transAxes, fontsize=10, bbox=dict(facecolor='none', edgecolor='black'))

plt.tight_layout()
plt.show()
# Out:
# --2023-12-04 00:45:46--  https://raw.githubusercontent.com/gabrield03/cs131/master/MiniProjectGroup7/ExtractData/IndustryByRating.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65754 (64K) [text/plain]
# Saving to: ‘dsjob3.csv’
#
# dsjob3.csv          100%[===================>]  64.21K  --.-KB/s    in 0.02s
#
# 2023-12-04 00:45:47 (2.71 MB/s) - ‘dsjob3.csv’ saved [65754/65754]

# %% [markdown]
# # Salary Range by Location
#
# Link to MinMaxSalaryByLocation.awk file: https://raw.githubusercontent.com/thipham00/cs131/master/MiniProjectGroup7/ExtractData/MinMaxSalaryByLocation.awk

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV files into a DataFrame without headers
df = pd.read_csv('https://raw.githubusercontent.com/thipham00/cs131/master/MiniProjectGroup7/ExtractData/MinMaxSalaryByLocation.csv', header=None, names=['Location', 'Salary'])
df1 = pd.read_csv('https://raw.githubusercontent.com/thipham00/cs131/master/MiniProjectGroup7/ExtractData/SalaryByLocation.csv', header=None, names=['Location', 'Salary'])

# Extract minimum and maximum salary values
df[['MinSalary', 'MaxSalary']] = df['Salary'].str.extract(r'\$(\d+)K\-\$(\d+)K')

# Extract data points for each location
locations = df1['Location'][1:].value_counts()

# Convert salary columns to numeric values
df['MinSalary'] = pd.to_numeric(df['MinSalary'])
df['MaxSalary'] = pd.to_numeric(df['MaxSalary'])

# Define RGB colors for each location
bar_colors = [(0.298, 0.447, 0.690), (0.867, 0.518, 0.322), (0.333, 0.659, 0.408), (0.768, 0.305, 0.321), (0.505, 0.447, 0.698),
              (0.576, 0.470, 0.376), (0.854, 0.545, 0.764), (0.549, 0.549, 0.549), (0.800, 0.725, 0.454), (0.392, 0.710, 0.803), (0.239, 0.412, 0)]

# Create figure with space for two subplots
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(20, 10), gridspec_kw={'width_ratios': [2, 1]})

# Plot the range plot with RGB-colored rectangles
for location, group in df.groupby('Location'):
    color = bar_colors[df['Location'].unique().tolist().index(location)]
    ax.bar(location, group['MaxSalary'].max() - group['MinSalary'].min(), bottom=group['MinSalary'].min(),
            color=color, edgecolor='none')  # Set edgecolor to 'none' to remove bar borders

    # Add text annotations for min and max values outside the bars
    ax.text(location, group['MinSalary'].min() - 6, f'{group["MinSalary"].min()}', ha='center', va='bottom', color='black', fontsize=11)
    ax.text(location, group['MaxSalary'].max() + 6, f'{group["MaxSalary"].max()}', ha='center', va='top', color='black', fontsize=11)

ax.set_title('Salary Range By Location (Min - Max)')
ax.set_xlabel('Location')
ax.set_ylabel('Salary Estimate (in thousands of $)')
ax.grid(False)
ax.set_ylim(0, ax.get_ylim()[1])
ax.set_yticks(range(0, int(ax.get_ylim()[1]) + 1, 25))

# Plot Pie Chart with the same colors as the bar chart
wedges, _, _ = ax2.pie(locations, labels=None, autopct='', colors=bar_colors)  # Set autopct to an empty string
ax2.set_title('Data Points by Location')

# Calculate n
total_data_points = sum(locations)
total_text = f"n = {total_data_points}"
ax2.text(0.5, -0.15, total_text, ha='center', va='center', transform=ax2.transAxes, fontsize=10, bbox=dict(facecolor='none', edgecolor='black'))

# Add legend for the bar chart and move it to the right
legend_labels = [f'{location} - {percentage:.1f}%' for location, percentage in zip(locations.index, (locations / total_data_points) * 100)]
ax2.legend(legend_labels, loc='upper left', bbox_to_anchor=(0.9, 0.5))  # Adjust the bbox_to_anchor parameter

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
